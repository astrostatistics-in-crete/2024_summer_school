# %% [markdown]
# <font size=6>**Life is unfair**</font>
#
# - - -
#
# _You are a PhD student. It is a pleasant mid-summer Friday evening. Your are packing your stuff, ready to go home and enjoy the weekend.<br>
# When $-$ unexpectedly $-$ you receive a phone call by your professor ..._
#
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
# "
# Hi $<$_your name_$>$,
#
# Ehrm ... I know this is a bit last minute but ... I promised my colleagues to create a model for a proposal they are submitting. Problem is, I completely forgot and the deadline is in one hour. I started working on some code but I had to drop it because I am currently attending a - hummm - conference?!
# "
# </div>
#
# &emsp; <font color='grey'>***<i>YMCA song by Village People starts in the background</i></font>
#
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
# "
# Anyways, point is: can you create me a quick model that predicts galaxy Star Formation Rates?<br>
# For the training, use the Hecate catalog: I will send you the link.  It has plenty of columns, but the snippet of code I wrote takes care of removing the irrelevant ones, and removes the NaN values as well.<br>
#
# Basically, the model shall predict the values in the column 'logSFR_HEC'.<br>
#
# I really don't care if you use only one, two, or any number of columns from the catalog. Also, I do not care if you use Least Squares fitting, Bayesian fitting, Machine Learning regression, or Deep Learning regression.
# I just need something that takes an X and predicts logSFR_HEC ... keep it simple!
#
# Make sure to hold out a test set, and plot the predicted _vs_ true values for that set. I will send you an image of the plot I expect you to produce.
# "
# </div>
#
# &emsp; <font color='grey'>***<i>Noise that totally resembles someone taking a sip of Margarita</i></font>
#
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
# "
# Ah, regarding the code $-$ I remember I paid good cash to send you to this fantastic Summer School for Astrostatistics in Malta. Or Crete, whatever. I mean, I think you can really copy-pasta the code from their excellent, magnificent notebooks. If you have to add too much code you are on the wrong path.
#
# I assume there are teachers and assistants in the room with you. They will not present anything else for the time being, but if you raise your hand they will come to help.
#
# Best of luck, no pressure. Ciao, ciao, gotta go-
# "
# </div>

# %% [markdown]
# - - -
#
# _In your mailbox, you received the link to Hecate catalog:_
#
# &emsp; https://hecate.ia.forth.gr/catalog.php
#
# _... and a sketch of the plot you are expected to produce:_
#
# <table><tr>
#     <td width=450>
#         <img src="attachment:expectation.png">
#     </td>
# </tr></table>

# %%
#EOF

# %%
#EOF

# %%
#EOF
